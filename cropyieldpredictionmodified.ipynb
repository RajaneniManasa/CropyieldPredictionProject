# %%
import pandas as pd
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
from sklearn import model_selection
from sklearn import metrics
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.model_selection import learning_curve
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# %%
def train(X_train,y_train,X_test):
 """ Trains and predicts dataset with a Random Forest classifier """
 clf=RandomForestClassifier(n_estimators=40,oob_score=True)
 clf.fit(X_train,y_train)
 print("The best classifier is: ",clf)
 scores = model_selection.cross_val_score(clf, X_train,y_train, cv=5)
 print(scores)
 print('Estimated score: %0.5f (+/- %0.5f)' % (scores.mean(), scores.std() / 2))
 title = 'Learning Curves (Random Forest)'
 y_pred = clf.predict(X_test)
 return y_test,y_pred
 return y_test,y_pred

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
 target_names=['Wheat','Rice','grams','pulses','corn']
 plt.imshow(cm, interpolation='nearest', cmap=cmap)
 plt.title(title)
 plt.colorbar()
 tick_marks = np.arange(len(target_names))
 plt.xticks(tick_marks, target_names, rotation=45)
 plt.yticks(tick_marks, target_names)
 plt.tight_layout()
 plt.ylabel('True label')
 plt.xlabel('Predicted label')
 plt.show()
mydata=pd.read_csv("C:/Users/jiten/OneDrive/Desktop/finalyield.csv")
mydata[0:11]
print(len(mydata))
X=mydata[[ 'Moisture','rainfall','Average Humidity','Mean Temp','max Temp','Min temp','alkaline','sandy','chalky','clay']].values
print(X.shape)
X[0:9]
y=mydata["millet yield"]
print(y.shape)
y[0:11]
print("spliting datasets in train and test dataset...\n")
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.20, random_state=44)
print("training datasets.......\n")
y_test,y_pred = train(X_train,y_train,X_test)
plt.figure(figsize=(5,2))
x = y_test
plt.hist (x, bins = 20, color = "green")
plt.title ("Crop yield Prediction")
plt.xlabel ("crop")
plt.ylabel ("Count")
plt.show ()
print ('Classification Accuracy on Test dataset: ' ,accuracy_score(y_test, y_pred))
cm=confusion_matrix (y_test, y_pred)
plot_confusion_matrix (cm)
print('Confusion matrix, without normalization')
print(cm)
print(metrics.classification_report(y_test,y_pred))
# Out:
# 3977
# (3977, 10)
# (3977,)
# spliting datasets in train and test dataset...
#
# training datasets.......
#
# The best classifier is:  RandomForestClassifier(n_estimators=40, oob_score=True)
# [0.99686028 0.99213836 0.99685535 0.99213836 0.99056604]
# Estimated score: 0.99371 (+/- 0.00132)
# Classification Accuracy on Test dataset:  0.9962311557788944
# Confusion matrix, without normalization
# [[257   0   0   0   1]
#  [  0 134   0   0   0]
#  [  1   0 154   0   0]
#  [  1   0   0   5   0]
#  [  0   0   0   0 243]]
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99       258
#          1.0       1.00      1.00      1.00       134
#          2.0       1.00      0.99      1.00       155
#          3.0       1.00      0.83      0.91         6
#          4.0       1.00      1.00      1.00       243
#
#     accuracy                           1.00       796
#    macro avg       1.00      0.96      0.98       796
# ...

# %%
import tkinter as tk
from tkinter import Message,Text
import pandas as pd
import tkinter.ttk as ttk
import tkinter.font as font

# %%
import tkinter as tk
from tkinter import Message,Text
import pandas as pd
import tkinter.ttk as ttk
import tkinter.font as font
window = tk.Tk()
window.title("Crop Yield Prediction")
window.geometry('1600x700+0+0')
window.configure(background='pink')
window.grid_rowconfigure(0, weight=1)
window.grid_columnconfigure(0, weight=1)
message = tk.Label(window, text="Crop Yield Prediction" ,bg="green" ,fg="WHITE" ,width=25,height=1,font=('times', 30, 'italic bold underline'))
message.place(x=400, y=20)
result=tk.StringVar()
lbl1 = tk.Label(window, text="Moisture", width=10 ,height=1 ,fg="red" ,bg="yellow" ,font=('times', 15, 'bold ') )
lbl1.place(x=60, y=100)
txt1 = tk.Entry(window, width=30,bd=5 ,bg="#B93B8F" ,fg="WHITE", font=('times', 15, ' bold '))
txt1.place(x=240, y=100)
lbl2 = tk.Label(window, text="rainfall", width=10 ,fg="red" ,bg="yellow" ,height=1 ,font=('times', 15, 'bold '))
lbl2.place(x=60, y=180)
txt2 = tk.Entry(window, width=30,bd=5 ,bg="#B93B8F", fg="WHITE", font=('times', 15, ' bold ') )
txt2.place(x=240, y=180)
lbl3 = tk.Label(window, text="avg humidity", width=10 ,height=1 ,fg="red", bg="yellow" ,font=('times',15, ' bold ') )
lbl3.place(x=60, y=260)
txt3 = tk.Entry(window, width=30,bd=5 ,bg="#B93B8F" ,fg="WHITE", font=('times', 15, ' bold '))
txt3.place(x=240, y=260)
lbl4 = tk.Label(window, text="mean temp", width=10 ,height=1 ,fg="red" ,bg="yellow" ,font=('times', 15, ' bold ') )
lbl4.place(x=60, y=340)
txt4 = tk.Entry(window,width=30,bd=5 ,bg="#B93B8F" ,fg="WHITE",font=('times', 15, ' bold '))
txt4.place(x=240, y=340)
lbl5 = tk.Label(window, text="max temp",width=10 ,height=1 ,fg="red" ,bg="yellow" ,font=('times',15, ' bold ') )
lbl5.place(x=60, y=420)
txt5 = tk.Entry(window,width=30,bd=5 ,bg="#B93B8F" ,fg="WHITE",font=('times', 15, ' bold '))
txt5.place(x=240, y=420)
lbl6 = tk.Label(window, text="min temp",width=10 ,height=1 ,fg="red" ,bg="yellow" ,font=('times',15, ' bold ') )
lbl6.place(x=60, y=500)
txt6 = tk.Entry(window, width=30,bd=5 ,bg="#B93B8F" ,fg="WHITE", font=('times', 15, ' bold '))
txt6.place(x=240, y=500)
lbl7 = tk.Label(window, text="alkaline", width=10 ,height=1 ,fg="red" ,bg="yellow" ,font=('times', 15,' bold ') )
lbl7.place(x=60, y=580)
txt7 = tk.Entry(window, width=30,bd=5 ,bg="#B93B8F" ,fg="WHITE", font=('times', 15, ' bold '))
txt7.place(x=240, y=580)
lbl8 = tk.Label(window, text="sandy", width=10 ,height=1 ,fg="red" ,bg="yellow" ,font=('times', 15, 'bold ') )
lbl8.place(x=700, y=100)
txt8 = tk.Entry(window, width=30,bd=5 ,bg="#B93B8F" ,fg="WHITE", font=('times', 15, ' bold '))
txt8.place(x=900, y=100)
lbl9 = tk.Label(window, text="chalky", width=10 ,height=1 ,fg="red" ,bg="yellow" ,font=('times', 15, 'bold ') )
lbl9.place(x=700, y=180)
txt9 = tk.Entry(window,width=30,bd=5 ,bg="#B93B8F" ,fg="WHITE", font=('times', 15, ' bold '))
txt9.place(x=900, y=180)
lbl10 = tk.Label (window, text="clay", width=10, height=1, fg="red", bg="yellow", font=('times', 15, 'bold ') )
lbl10.place(x=700, y=260)
txt10 = tk.Entry(window, width=30,bd=5 ,bg="#B93B8F" ,fg="WHITE", font=('times', 15, ' bold '))
txt10.place(x=900, y=260)
lbl14 = tk.Label (window, text="Result", width=5 ,height=1 ,fg="red" ,bg="yellow" ,font=('times', 15, 'bold ') )
lbl14.place(x=850, y=580)
txt14 = tk.Entry(window, width=20,bd=5 ,bg="#B93B8F" , textvariable=result ,fg="WHITE",font=('times', 15, ' bold '))
txt14.place(x=950, y=580)
def qexit():
    window.destroy()
def submit1():
    l=[]
    a=int(txt1.get())
    l.append(a)
    b=int(txt2.get())
    l.append(b)
    c=int(txt3.get())
    l.append(c)
    d=int(txt4.get())
    l.append(d)
    e=int(txt5.get())
    l.append(e)
    f=int(txt6.get())
    l.append(f)
    g=int(txt7.get())
    l.append(g)
    h=int(txt8.get())
    l.append(h)
    i=int(txt9.get())
    l.append(i)
    j=int(txt10.get())
    l.append(j)
    l2=[l]
    
    import pandas as pd
    from sklearn import preprocessing
    mydata=pd.read_csv("C:/Users/jiten/OneDrive/Desktop/finalyield.csv")
    X=mydata[['Moisture','rainfall','Average Humidity','Mean Temp','max Temp','Min temp','alkaline','sandy','chalky','clay']].values
    y=mydata["millet yield"]
    from sklearn.model_selection import train_test_split
    from sklearn.metrics import classification_report
    from sklearn.metrics import confusion_matrix
    from sklearn.ensemble import RandomForestClassifier
    from sklearn import model_selection
    clf=RandomForestClassifier(n_estimators=40,oob_score=True)
    X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.20, random_state=44)
    clf.fit(X_train,y_train)
    scores = model_selection.cross_val_score(clf, X_train,y_train, cv=5)
    title = 'Learning Curves (Random Forest)'
    lr_predict_test = clf.predict(l2)
    lr=""
    if lr_predict_test==0:
        lr="Rice"
    elif lr_predict_test==1:
        lr="Wheat"
    elif lr_predict_test==2:
        lr="Corn"
    elif lr_predict_test==3:
        lr="pulses"
    elif lr_predict_test==4:
        lr="grams"
    else:
        lr="others"
    result.set(lr)

btnsubmit=tk.Button(window,text="Submit",fg="red",bg="yellow",width=5,height=1,font=("times",15,"bold"),command=submit1)
btnsubmit.place(x=700,y=580)
btnexit=tk.Button(window,text="Exit",fg="red",bg="yellow",width=5,height=1,font=("times",15,"bold"),command=qexit)
btnexit.place(x=1200,y=580)

window.mainloop()

# %%
import pandas as pd
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
 target_names=['Rice','Wheat','flour','blackgram']
 plt.imshow(cm, interpolation='nearest', cmap=cmap)
 plt.title(title)
 plt.colorbar()
 tick_marks = np.arange(len(target_names))
 plt.xticks(tick_marks, target_names, rotation=45)
 plt.yticks(tick_marks, target_names)
 plt.tight_layout()
 plt.ylabel('True label')
 plt.xlabel('Predicted label')
mydata=pd.read_csv("C:/Users/jiten/OneDrive/Desktop/finalyield.csv")
mydata[0:11]
print (len(mydata))
print(mydata)
X=mydata[['Moisture','rainfall','Average Humidity','Mean Temp','max Temp','alkaline','sandy','chalky','clay']].values
print(X.shape)
X[0:10]
y=mydata["millet yield"]
print(y.shape)
y[0:11]
#from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split
X_trainset,X_testset,y_trainset,y_testset=train_test_split(X,y,test_size=0.2,random_state=4)
print('Trainset:',X_trainset.shape,y_trainset.shape) #rows matches
print('Testset:',X_testset.shape,y_testset.shape)
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
lr_model = LogisticRegression(C=0.7, random_state=42) # create random forest object
lr_model.fit(X_trainset, y_trainset.ravel())
from sklearn import metrics
lr_predict_test = lr_model.predict(X_testset)
print(lr_predict_test)
# training metrics
print("Accuracy : {0:.4f}".format(metrics.accuracy_score(y_testset, lr_predict_test)))
print()
print ("Confusion Matrix")
print ("{0}".format (metrics.confusion_matrix(y_testset,lr_predict_test)))
cm=metrics.confusion_matrix (y_testset, lr_predict_test)
plot_confusion_matrix (cm)
print(" ")
print(" Classification Report ")
print(metrics.classification_report(y_testset, lr_predict_test))
# Out:
# 3977
#       Unnamed: 0   Moisture  rainfall  Average Humidity  Mean Temp  max Temp  \
# 0              0  12.801685  0.012360                57         62        71
# 1              1  12.851654  0.004172                57         58        73
# 2              2  12.776773  0.000000                56         58        69
# 3              3  12.942001  0.031747                62         56        70
# 4              4  12.984652  0.000000                65         56        70
# ...          ...        ...       ...               ...        ...       ...
# 3972        3972  12.959730  0.000000                30         72        85
# 3973        3973  12.985416  0.000000                30         70        87
# 3974        3974  12.947405  0.000300                33         70        86
# 3975        3975  12.771689  0.000000                35         69        85
# 3976        3976  12.845779  0.010131                36         70        86
#
# ...
